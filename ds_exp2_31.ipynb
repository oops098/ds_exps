# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load and read dataset

# %%
df=pd.read_csv('ElectricCarData_Clean.csv')
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6         233.0
# 1    Volkswagen                         ID.3 Pure      10.0         160.0
# 2      Polestar                                 2       4.7         210.0
# 3           BMW                              iX3        6.8         180.0
# 4         Honda                                e        9.5         145.0
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5         160.0
# 99         Audi     e-tron S Sportback 55 quattro       4.5         210.0
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9         200.0
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1         200.0
# 102       Byton                 M-Byte 95 kWh 2WD       7.5         190.0
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %% [markdown]
# Head prints top 5 contents of the data

# %%
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6         233.0
# 1  Volkswagen                       ID.3 Pure      10.0         160.0
# 2    Polestar                               2       4.7         210.0
# 3         BMW                            iX3        6.8         180.0
# 4       Honda                              e        9.5         145.0
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D    5.0      55480
# ...

# %% [markdown]
# Displays the bottom 5 contents

# %%
df.tail()
# Out:
#        Brand                            Model  AccelSec  TopSpeed_KmH  \
# 98   Nissan                       Ariya 63kWh       7.5           160
# 99     Audi     e-tron S Sportback 55 quattro       4.5           210
# 100  Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101  Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102   Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 98        330              191            440         Yes        FWD
# 99        335              258            540         Yes        AWD
# 100       325              194            440         Yes        AWD
# 101       375              232            450         Yes        AWD
# 102       400              238            480         Yes        AWD
#
#        PlugType  BodyStyle Segment  Seats  PriceEuro
# 98   Type 2 CCS  Hatchback       C      5      45000
# ...

# %% [markdown]
# Descibe:- Gives the data about the dataset

# %%
df.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000

# %%
df.describe(include='all')
# Out:
#          Brand          Model    AccelSec  TopSpeed_KmH    Range_Km  \
# count      103            103  103.000000    103.000000  103.000000
# unique      33            102         NaN           NaN         NaN
# top     Tesla   e-Soul 64 kWh         NaN           NaN         NaN
# freq        13              2         NaN           NaN         NaN
# mean       NaN            NaN    7.396117    179.194175  338.786408
# std        NaN            NaN    3.017430     43.573030  126.014444
# min        NaN            NaN    2.100000    123.000000   95.000000
# 25%        NaN            NaN    5.100000    150.000000  250.000000
# 50%        NaN            NaN    7.300000    160.000000  340.000000
# 75%        NaN            NaN    9.000000    200.000000  400.000000
# max        NaN            NaN   22.400000    410.000000  970.000000
#
#         Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain    PlugType  \
# count        103.000000            103         103        103         103
# ...

# %% [markdown]
# Gives the info about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %% [markdown]
# Identify null values

# %%
df.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       1
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              1
# PriceEuro          0
# dtype: int64

# %%
df.isnull()
# Out:
#      Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0    False  False     False         False     False            False
# 1    False  False     False         False     False            False
# 2    False  False     False         False     False            False
# 3    False  False     False         False     False            False
# 4    False  False     False         False     False            False
# ..     ...    ...       ...           ...       ...              ...
# 98   False  False     False         False     False            False
# 99   False  False     False         False     False            False
# 100  False  False     False         False     False            False
# 101  False  False     False         False     False            False
# 102  False  False     False         False     False            False
#
#      FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  \
# ...

# %% [markdown]
# Replace null values by mean,median,random

# %%
df['Seats'].fillna(df['Seats'].mean(), inplace=True)
df['Seats']
# Out:
# 0      5.0
# 1      5.0
# 2      5.0
# 3      5.0
# 4      4.0
#       ...
# 98     5.0
# 99     5.0
# 100    5.0
# 101    5.0
# 102    5.0
# Name: Seats, Length: 103, dtype: float64

# %%
plt.figure(figsize=(16,9))
plt.title("EV VEHICLES")
plt.grid()
plt.xlabel('Acceleration per sec')
plt.ylabel('Brand')
plt.scatter(df['AccelSec'],df['Brand'])

# %%
plt.figure(figsize=(16,9))
plt.title("EV VEHICLES")
plt.xlabel('Acceleration per sec')
plt.ylabel('Brand')
plt.bar(df['AccelSec'],df['Brand'])
# Out:
# <BarContainer object of 103 artists>

# %% [markdown]
# USING BOXPLOT FOR OUTLIERS

# %%
plt.boxplot(df['AccelSec'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7dec1047e6b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7dec1047ebf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7dec1047e410>],
#  'medians': [<matplotlib.lines.Line2D at 0x7dec1047f130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7dec1047f3d0>],
#  'means': []}

# %%
import seaborn as sns

# %%
sns.countplot(x=df['Range_Km'])
# Out:
# <Axes: xlabel='Range_Km', ylabel='count'>

# %%
sns.pairplot(df)
